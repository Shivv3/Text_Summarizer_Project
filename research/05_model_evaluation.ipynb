# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\shiva\\OneDrive\\Desktop\\Work\\NLP\\Projects\\Text_Summarizer_Project\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\shiva\\OneDrive\\Desktop\\Work\\NLP\\Projects\\Text_Summarizer_Project'

# %% [markdown]
# Defining an Entity:

# %%
from dataclasses import dataclass
from pathlib import Path

class ModelEvaluationConfig:
    def __init__(self, root_dir, data_path, model_path, tokenizer_path, metric_file_name):
        self.root_dir = root_dir
        self.data_path = data_path
        self.model_path = model_path
        self.tokenizer_path = tokenizer_path
        self.metric_file_name = metric_file_name

# %% [markdown]
# Defining the configuration Manager:

# %%
from textSummarizer.constants import *
from textSummarizer.utils.common import read_yaml,create_directories

# %%
class ConfigurationManager:
    
    #Defining a constructor with following paramteres:
    def __init__(self,config_filepath = CONFIG_FILE_PATH, params_filepath = PARAMS_FILE_PATH):

        #Obtaining the config from the file_path:
        self.config = read_yaml(config_filepath)
        
        #Obtaining the paramters from the file_path:
        self.params = read_yaml(params_filepath)

        #Creating a new artifact: root folder:
        create_directories([self.config.artifacts_root])


    #Defining a function to Obtain model evaluation:
    def get_model_evaluation_config(self) -> ModelEvaluationConfig:

        #Obtaining the configuration of the current model:
        config = self.config.model_evaluation

        #Creating directory:
        create_directories([config.root_dir])

        #Defining model evaluation configuration:
        model_evaluation_config = ModelEvaluationConfig(
            root_dir = config.root_dir,
            data_path = config.data_path,
            model_path = config.model_path,
            tokenizer_path = config.tokenizer_path,
            metric_file_name = config.metric_file_name
        )

        #Returning the Model Evaluation config:
        return model_evaluation_config

# %% [markdown]
# Creating components:

# %%
pip install evaluate
# Out:
# Requirement already satisfied: evaluate in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (0.4.3)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from evaluate) (2.2.4)
# Requirement already satisfied: dill in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from evaluate) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.12.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from evaluate) (0.29.3)
# Requirement already satisfied: packaging in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from datasets>=2.0.0->evaluate) (19.0.1)
# Requirement already satisfied: aiohttp in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from datasets>=2.0.0->evaluate) (3.11.14)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from requests>=2.19.0->evaluate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from requests>=2.19.0->evaluate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from requests>=2.19.0->evaluate) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from pandas->evaluate) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from pandas->evaluate) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.18.3)
# Requirement already satisfied: six>=1.5 in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rouge_metric
# Out:
# Requirement already satisfied: rouge_metric in c:\users\shiva\onedrive\desktop\work\nlp\projects\text_summarizer_project\textsummarization\lib\site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline, set_seed
from datasets import load_from_disk
import matplotlib.pyplot as plt
import pandas as pd
from evaluate import load
metric = load("rouge")
from evaluate import load as load_metric
from transformers import AutoModelForSeq2SeqLM,AutoTokenizer
import nltk
from nltk.tokenize import sent_tokenize
from tqdm import tqdm
import torch
import json

# %%
#Creating components for Model_Evaluation:
class ModelEvaluation:

    #Defining the constructor:
    def __init__(self,config: ModelEvaluationConfig):
        self.config = config


    def generate_batch_sized_chunks(self, list_of_elements, batch_size):
        for i in range(0, len(list_of_elements), batch_size):
            batch = list_of_elements[i : i + batch_size]
            if not batch:  # Prevents yielding empty batch
                break
            print(f"Processing batch {i // batch_size + 1}/{(len(list_of_elements) + batch_size - 1) // batch_size}")
            yield batch



    
    # Define the device
    device = "cuda" if torch.cuda.is_available() else "cpu"

    #A function to calculate the metric of the test dataset:
    def calculate_metric_on_test_ds(self,dataset,metric,model,tokenizer,batch_size = 4,device = device,column_text = "article",column_summary = "highlights"):
        article_batches = list(self.generate_batch_sized_chunks(dataset[column_text],batch_size))
        target_batches = list(self.generate_batch_sized_chunks(dataset[column_summary],batch_size))

        for article_batch,target_batch in tqdm(
            zip(article_batches,target_batches),total = len(article_batches)):

            inputs = tokenizer(article_batch,max_length = 1024,truncation = True,padding = "max_length",return_tensors = "pt")

            summaries = model.generate(input_ids = inputs["input_ids"].to(device),
                                        attention_mask = inputs["attention_mask"].to(device),
                                        length_penalty = 0.8,num_beams = 8, max_length = 128)

            ''' parameter for length penalty ensures that the model does not generate sequences that are too long.'''

            # Finally, we decode the generated texts,
            # replace the token, and add the decoded texts with the references to the metric:
            decoded_summaries = [tokenizer.decode(s,skip_special_tokens = True,clean_up_tokenization_spaces = True) for s in summaries]

            decoded_summaries = [d.replace("", " ") for d in decoded_summaries]

            metric.add_batch(predictions = decoded_summaries,references = target_batch)

        score = metric.compute()
        return score


    #A function to evaluate metric:
    def evaluate(self):

        device = "cuda" if torch.cuda.is_available() else "cpu"
        tokenizer = AutoTokenizer.from_pretrained(self.config.tokenizer_path)
        model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(self.config.model_path).to(device)

        #Loading data:
        dataset_samsum_pt = load_from_disk(self.config.data_path)

        rouge_names = ["rouge1","rouge2","rougeL","rougeLsum"]
        rouge_metric = load_metric('rouge') 

        # Defining the score:
        score = self.calculate_metric_on_test_ds(
            dataset_samsum_pt['test'], rouge_metric,model_pegasus,tokenizer,
            column_text = "dialogue",column_summary = "summary"
        )

        with open("artifacts/model_evaluation/rouge_raw_scores.json", "w") as f:
            json.dump({k: float(v) for k, v in score.items()}, f, indent=4)

        #Defining the rouge dictionary for metrices:
        rouge_dict = dict((rn,score[rn]) for rn in rouge_names)

        #Converting the metric dictionary into dataframe:
        df = pd.DataFrame(rouge_dict,index = ['pegasus'])

        #Saving the dataframe in csv format:
        df.to_csv(self.config.metric_file_name,index = False)

# %% [markdown]
# Defining the PipeLine:

# %%
try:
    config = ConfigurationManager()
    model_evaluation_config = config.get_model_evaluation_config()
    model_evaluation_config = ModelEvaluation(config = model_evaluation_config)
    model_evaluation_config.evaluate()

except Exception as e:
    raise e
# Out:
# [2025-04-05 15:26:40,024: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-04-05 15:26:40,032: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-04-05 15:26:40,032: INFO: common: created directory at: artifacts]
# [2025-04-05 15:26:40,041: INFO: common: created directory at: artifacts/model_evaluation]
# Processing batch 1/205
# Processing batch 2/205
# Processing batch 3/205
# Processing batch 4/205
# Processing batch 5/205
# Processing batch 6/205
# Processing batch 7/205
# Processing batch 8/205
# Processing batch 9/205
# Processing batch 10/205
# Processing batch 11/205
# Processing batch 12/205
# Processing batch 13/205
# Processing batch 14/205
# Processing batch 15/205
# Processing batch 16/205
# Processing batch 17/205
# Processing batch 18/205
# Processing batch 19/205
# Processing batch 20/205
# Processing batch 21/205
# Processing batch 22/205
# Processing batch 23/205
# Processing batch 24/205
# Processing batch 25/205
# Processing batch 26/205
# Processing batch 27/205
# Processing batch 28/205
# Processing batch 29/205
# Processing batch 30/205
# Processing batch 31/205
# Processing batch 32/205
# Processing batch 33/205
# Processing batch 34/205
# Processing batch 35/205
# Processing batch 36/205
# Processing batch 37/205
# Processing batch 38/205
# Processing batch 39/205
# Processing batch 40/205
# Processing batch 41/205
# Processing batch 42/205
# Processing batch 43/205
# Processing batch 44/205
# Processing batch 45/205
# Processing batch 46/205
# Processing batch 47/205
# Processing batch 48/205
# Processing batch 49/205
# Processing batch 50/205
# Processing batch 51/205
# Processing batch 52/205
# Processing batch 53/205
# Processing batch 54/205
# Processing batch 55/205
# Processing batch 56/205
# Processing batch 57/205
# Processing batch 58/205
# Processing batch 59/205
# Processing batch 60/205
# Processing batch 61/205
# Processing batch 62/205
# Processing batch 63/205
# Processing batch 64/205
# Processing batch 65/205
# Processing batch 66/205
# Processing batch 67/205
# Processing batch 68/205
# Processing batch 69/205
# Processing batch 70/205
# Processing batch 71/205
# Processing batch 72/205
# Processing batch 73/205
# Processing batch 74/205
# Processing batch 75/205
# Processing batch 76/205
# Processing batch 77/205
# Processing batch 78/205
# Processing batch 79/205
# Processing batch 80/205
# Processing batch 81/205
# Processing batch 82/205
# Processing batch 83/205
# Processing batch 84/205
# Processing batch 85/205
# Processing batch 86/205
# Processing batch 87/205
# Processing batch 88/205
# Processing batch 89/205
# Processing batch 90/205
# Processing batch 91/205
# Processing batch 92/205
# Processing batch 93/205
# Processing batch 94/205
# Processing batch 95/205
# Processing batch 96/205
# Processing batch 97/205
# Processing batch 98/205
# Processing batch 99/205
# Processing batch 100/205
# Processing batch 101/205
# Processing batch 102/205
# Processing batch 103/205
# Processing batch 104/205
# Processing batch 105/205
# Processing batch 106/205
# Processing batch 107/205
# Processing batch 108/205
# Processing batch 109/205
# Processing batch 110/205
# Processing batch 111/205
# Processing batch 112/205
# Processing batch 113/205
# Processing batch 114/205
# Processing batch 115/205
# Processing batch 116/205
# Processing batch 117/205
# Processing batch 118/205
# Processing batch 119/205
# Processing batch 120/205
# Processing batch 121/205
# Processing batch 122/205
# Processing batch 123/205
# Processing batch 124/205
# Processing batch 125/205
# Processing batch 126/205
# Processing batch 127/205
# Processing batch 128/205
# Processing batch 129/205
# Processing batch 130/205
# Processing batch 131/205
# Processing batch 132/205
# Processing batch 133/205
# Processing batch 134/205
# Processing batch 135/205
# Processing batch 136/205
# Processing batch 137/205
# Processing batch 138/205
# Processing batch 139/205
# Processing batch 140/205
# Processing batch 141/205
# Processing batch 142/205
# Processing batch 143/205
# Processing batch 144/205
# Processing batch 145/205
# Processing batch 146/205
# Processing batch 147/205
# Processing batch 148/205
# Processing batch 149/205
# Processing batch 150/205
# Processing batch 151/205
# Processing batch 152/205
# Processing batch 153/205
# Processing batch 154/205
# Processing batch 155/205
# Processing batch 156/205
# Processing batch 157/205
# Processing batch 158/205
# Processing batch 159/205
# Processing batch 160/205
# Processing batch 161/205
# Processing batch 162/205
# Processing batch 163/205
# Processing batch 164/205
# Processing batch 165/205
# Processing batch 166/205
# Processing batch 167/205
# Processing batch 168/205
# Processing batch 169/205
# Processing batch 170/205
# Processing batch 171/205
# Processing batch 172/205
# Processing batch 173/205
# Processing batch 174/205
# Processing batch 175/205
# Processing batch 176/205
# Processing batch 177/205
# Processing batch 178/205
# Processing batch 179/205
# Processing batch 180/205
# Processing batch 181/205
# Processing batch 182/205
# Processing batch 183/205
# Processing batch 184/205
# Processing batch 185/205
# Processing batch 186/205
# Processing batch 187/205
# Processing batch 188/205
# Processing batch 189/205
# Processing batch 190/205
# Processing batch 191/205
# Processing batch 192/205
# Processing batch 193/205
# Processing batch 194/205
# Processing batch 195/205
# Processing batch 196/205
# Processing batch 197/205
# Processing batch 198/205
# Processing batch 199/205
# Processing batch 200/205
# Processing batch 201/205
# Processing batch 202/205
# Processing batch 203/205
# Processing batch 204/205
# Processing batch 205/205
# Processing batch 1/205
# Processing batch 2/205
# Processing batch 3/205
# Processing batch 4/205
# Processing batch 5/205
# Processing batch 6/205
# Processing batch 7/205
# Processing batch 8/205
# Processing batch 9/205
# Processing batch 10/205
# Processing batch 11/205
# Processing batch 12/205
# Processing batch 13/205
# Processing batch 14/205
# Processing batch 15/205
# Processing batch 16/205
# Processing batch 17/205
# Processing batch 18/205
# Processing batch 19/205
# Processing batch 20/205
# Processing batch 21/205
# Processing batch 22/205
# Processing batch 23/205
# Processing batch 24/205
# Processing batch 25/205
# Processing batch 26/205
# Processing batch 27/205
# Processing batch 28/205
# Processing batch 29/205
# Processing batch 30/205
# Processing batch 31/205
# Processing batch 32/205
# Processing batch 33/205
# Processing batch 34/205
# Processing batch 35/205
# Processing batch 36/205
# Processing batch 37/205
# Processing batch 38/205
# Processing batch 39/205
# Processing batch 40/205
# Processing batch 41/205
# Processing batch 42/205
# Processing batch 43/205
# Processing batch 44/205
# Processing batch 45/205
# Processing batch 46/205
# Processing batch 47/205
# Processing batch 48/205
# Processing batch 49/205
# Processing batch 50/205
# Processing batch 51/205
# Processing batch 52/205
# Processing batch 53/205
# Processing batch 54/205
# Processing batch 55/205
# Processing batch 56/205
# Processing batch 57/205
# Processing batch 58/205
# Processing batch 59/205
# Processing batch 60/205
# Processing batch 61/205
# Processing batch 62/205
# Processing batch 63/205
# Processing batch 64/205
# Processing batch 65/205
# Processing batch 66/205
# Processing batch 67/205
# Processing batch 68/205
# Processing batch 69/205
# Processing batch 70/205
# Processing batch 71/205
# Processing batch 72/205
# Processing batch 73/205
# Processing batch 74/205
# Processing batch 75/205
# Processing batch 76/205
# Processing batch 77/205
# Processing batch 78/205
# Processing batch 79/205
# Processing batch 80/205
# Processing batch 81/205
# Processing batch 82/205
# Processing batch 83/205
# Processing batch 84/205
# Processing batch 85/205
# Processing batch 86/205
# Processing batch 87/205
# Processing batch 88/205
# Processing batch 89/205
# Processing batch 90/205
# Processing batch 91/205
# Processing batch 92/205
# Processing batch 93/205
# Processing batch 94/205
# Processing batch 95/205
# Processing batch 96/205
# Processing batch 97/205
# Processing batch 98/205
# Processing batch 99/205
# Processing batch 100/205
# Processing batch 101/205
# Processing batch 102/205
# Processing batch 103/205
# Processing batch 104/205
# Processing batch 105/205
# Processing batch 106/205
# Processing batch 107/205
# Processing batch 108/205
# Processing batch 109/205
# Processing batch 110/205
# Processing batch 111/205
# Processing batch 112/205
# Processing batch 113/205
# Processing batch 114/205
# Processing batch 115/205
# Processing batch 116/205
# Processing batch 117/205
# Processing batch 118/205
# Processing batch 119/205
# Processing batch 120/205
# Processing batch 121/205
# Processing batch 122/205
# Processing batch 123/205
# Processing batch 124/205
# Processing batch 125/205
# Processing batch 126/205
# Processing batch 127/205
# Processing batch 128/205
# Processing batch 129/205
# Processing batch 130/205
# Processing batch 131/205
# Processing batch 132/205
# Processing batch 133/205
# Processing batch 134/205
# Processing batch 135/205
# Processing batch 136/205
# Processing batch 137/205
# Processing batch 138/205
# Processing batch 139/205
# Processing batch 140/205
# Processing batch 141/205
# Processing batch 142/205
# Processing batch 143/205
# Processing batch 144/205
# Processing batch 145/205
# Processing batch 146/205
# Processing batch 147/205
# Processing batch 148/205
# Processing batch 149/205
# Processing batch 150/205
# Processing batch 151/205
# Processing batch 152/205
# Processing batch 153/205
# Processing batch 154/205
# Processing batch 155/205
# Processing batch 156/205
# Processing batch 157/205
# Processing batch 158/205
# Processing batch 159/205
# Processing batch 160/205
# Processing batch 161/205
# Processing batch 162/205
# Processing batch 163/205
# Processing batch 164/205
# Processing batch 165/205
# Processing batch 166/205
# Processing batch 167/205
# Processing batch 168/205
# Processing batch 169/205
# Processing batch 170/205
# Processing batch 171/205
# Processing batch 172/205
# Processing batch 173/205
# Processing batch 174/205
# Processing batch 175/205
# Processing batch 176/205
# Processing batch 177/205
# Processing batch 178/205
# Processing batch 179/205
# Processing batch 180/205
# Processing batch 181/205
# Processing batch 182/205
# Processing batch 183/205
# Processing batch 184/205
# Processing batch 185/205
# Processing batch 186/205
# Processing batch 187/205
# Processing batch 188/205
# Processing batch 189/205
# Processing batch 190/205
# Processing batch 191/205
# Processing batch 192/205
# Processing batch 193/205
# Processing batch 194/205
# Processing batch 195/205
# Processing batch 196/205
# Processing batch 197/205
# Processing batch 198/205
# Processing batch 199/205
# Processing batch 200/205
# Processing batch 201/205
# Processing batch 202/205
# Processing batch 203/205
# Processing batch 204/205
# Processing batch 205/205
# 100%|██████████| 205/205 [2:39:27<00:00, 46.67s/it]
# [2025-04-05 18:06:17,405: INFO: rouge_scorer: Using default tokenizer.]
